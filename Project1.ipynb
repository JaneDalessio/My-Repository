# %% [markdown]
# # Data 200 Project #1

# %% [markdown]
# ## Jane Dalessio
# ### Data 200 01, Spring 2025
# ### Due: 3/28 11:59 p.m.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# > #### (1) Import the data into a Jupyter notebook and print the first 5 rows.

# %%
data = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# > #### (2) Retrieve general information about the data using info.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# > #### (3)	Create a set of descriptive statistics for the data.

# %%
data.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# > #### (4) Determine whether the tabular data is TidyData.

# %%
print(data.head())
print(data.columns)
print(data.duplicated().sum())
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# > #### (5) If it is TidyData, explain how it meets each of the 3 traits. If it is not, apply transformations to make it TidyData.

# %% [markdown]
# I have concluded that my data is TidyData. First, I headed the data frame to conclude that each row is one observation. Next, I printed the data columns where I can see that each columns represents a distinct variable. Finally, by running 'print(data.duplicated().sum())' I can tell that each cell corresponds to only one observation because the sum comes back as 0.

# %% [markdown]
# > #### (6) Within your dataset, group the data based upon a variable and calculate 3 different aggregations. If your data are not suitable to grouping, just calculate the 3 aggregations for the whole dataset. What do these aggregations suggest about the data?

# %%
numeric_columns = ["streams", "danceability_%", "energy_%"]
for col in numeric_columns:
    data[col] = pd.to_numeric(data[col], errors="coerce")
# I kept getting an error and concluded that some of the numbers were actually strings, so I ran this to make sure all the values are numeric

aggregations = data.groupby("key").agg({"streams": "mean", "danceability_%": "median",  "instrumentalness_%": "mean"}).reset_index()

aggregations
# Out:
#    key       streams  danceability_%  instrumentalness_%
# 0    A  4.088414e+08            67.0            2.386667
# 1   A#  5.524754e+08            71.0            0.298246
# 2    B  5.193480e+08            74.0            1.197531
# 3   C#  6.042802e+08            70.0            1.241667
# 4    D  5.295256e+08            68.0            1.395062
# 5   D#  5.530365e+08            66.0            2.909091
# 6    E  5.774972e+08            66.0            2.354839
# 7    F  4.684464e+08            67.0            2.595506
# 8   F#  5.223632e+08            67.0            0.534247
# 9    G  4.525994e+08            70.0            1.583333
# 10  G#  4.769119e+08            70.0            1.780220

# %% [markdown]
# By aggregating the data by average streams, I found that among the 953 top-streamed songs on Spotify in 2023, those in the key of C# had the highest average streams. Next, I analyzed the median danceability percentage for songs grouped by key and discovered that songs in the key of B had the highest median danceability. Lastly, I examined the average instrumentalness percentage by key, revealing that songs in the key of F had the highest average instrumentalness, while those in A# had the lowest.

# %% [markdown]
# > #### (7)	Create two different types of visualizations with your dataset. These must be different kinds of visualizations (ex. scatterplot and histogram, not two histograms). Label them appropriately. Outline what they mean.

# %%
plt.scatter(data['released_year'], data['speechiness_%'], alpha = 0.7, color = 'purple')
plt.xlabel(' Song Release Year ')
plt.ylabel('Amount of Spoken Words (%)')
plt.title('Correlation Between Release Year and Spoken Words Top Spotify Songs (2023)')
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between the amount of spoken words in a song (speechiness) and its release year. From the graph, it seems that there is a weak positive correlation between the year a song was released and the amount of spoken words in that song, with more recent songs appearing to have higher speechiness scores. However, the relationship is not strong enough to draw a definitive conclusion or form a robust hypothesis.

# %%
plt.hist(data['artist_count'], color = 'orange', bins=range(1, data['artist_count'].max() + 1))
plt.xlabel('Number of Artists per Song')
plt.ylabel('Frequency')
plt.title('Distribution of Artist Count in Top Spotify Songs from 2023')
plt.show()

# %% [markdown]
# This graph illustrates the distribution of the number of artists featured in the top songs of 2023. From the data, it is apparent that most of these popular songs were created by solo artists. However, there are also songs featuring up to seven artists. Overall, the trend shows that the majority of top songs this year were primarily performed by a single artist.

# %% [markdown]
# > #### (8) Examining your data and determine if a relationship exists between two of the variables. If your data are not suited to that task, determine if a general trend or pattern is present. Write up your findings (250 words).

# %% [markdown]
# In the scatter plot above, I observe a potential correlation between the speechiness of a song and the year it was released. Although I don't have enough data to fully support this hypothesis, I believe that more recent songs tend to have a higher level of speechiness than songs from over 40 years ago. However, it's also true that some songs made today still have similar levels of spoken words as songs from the 1950s. One thing I noticed is that none of the songs from before 1990 had a speechiness rating higher than 15%.
# It's important to remember that this graph only shows the top songs of 2023 from one specific platform, so the data may not reflect broader trends across different years or genres. Still, based on the data, it seems that genres like rap and hip-hop, which became popular around the 90s and 2000s, may have contributed to the rise of spoken word in songs. These genres are known for their lyrical focus, which could explain the higher speechiness scores in more recent music.
# In conclusion, while the data suggests a correlation between the release year and speechiness, there isn't enough data to draw a strong conclusion. With a more comprehensive dataset, I believe I could find a stronger correlation, especially when looking at how genres like rap and hip-hop have influenced the amount of spoken words in popular music.

# %% [markdown]
# > #### (9)	Evaluate based upon the current methods how confident you can be with this hypothesis and map out some next steps of how you might go about more credibly (150 words)

# %% [markdown]
# I cannot be very confident in this hypothesis given the limitations of my dataset, which only includes the top songs from one platform in a single year. This data isn’t representative of all music. However, with a more comprehensive dataset, I could potentially identify a stronger correlation. One approach could be to incorporate genres, sorting the data by genre to test whether rap and hip-hop songs have higher speechiness ratings. I could also explore how popularity factors into the results, since my current data is based on the most-streamed songs of the year. My only peice of 'proof' that makes me confident with my conclusion about the emerging genres and hip-hop and rap is that none of the songs from before 1990 had a speechiness rating higher than 15%. While I can't draw strong conclusions from this data, my next steps would involve finding a larger dataset and analyzing it in a similar way to see if the same trend emerges.

# %% [markdown]
# > #### (10)	Write a brief statement on what additional data you may need in your analysis. Where could you possibly locate it? (100 words)

# %% [markdown]
# A more robust dataset I could look for would be the top 50 or 100 songs from each year between 1950 and 2025. While this would be a large dataset and potentially hard to find, I could focus on a smaller range, like 1950-2000. Since streaming platforms didn’t exist in the 1950s, I’d need to look at other data sources, such as top-selling albums. For more recent years, streaming data would provide a clearer picture. A feasible approach might be to gather multiple Spotify datasets from different years and merge them for a broader analysis.
